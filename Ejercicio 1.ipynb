# %% [markdown]
# <h1> Autobiografia </h1>

# %% [markdown]
# <h3> Informacion </h3>

# %% [markdown]
# Soy <strong>Andres Sanche Diez de Bonilla</strong>,
# naci el 23 de enero de 1994 en la  [Ciudad de Mexico](https://en.wikipedia.org/wiki/Mexico_City)
# Soy el menor de 4 hermanos. Soy una persona activa que le gusta mucho practicar deportes al aire libre al igual que verlos en la tele.

# %% [markdown]
# <h3> Foto </h3>

# %% [markdown]
# ![IMG_20190106_210340_843.jpg](attachment:IMG_20190106_210340_843.jpg)

# %% [markdown]
# <h3> Hobbies </h3>

# %% [markdown]
# * <font color="red">Beisbol</font>
# * <font color="green">Bici de Montaña</font>
# * <font color="Blue">Futbol</font>
# * <font color="orange">Tenis</font>
# * <font color="brown">Hike</font>
# * <font color="purpule">Surf</font>
